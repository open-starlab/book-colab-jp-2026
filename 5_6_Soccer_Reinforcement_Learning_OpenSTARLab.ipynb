# %% [markdown]
# # ⚽ 5.6 RLearnパッケージを用いたデータからの強化学習
# World Cup 2022のトラッキング・イベントデータを用いて、データからの強化学習の実装と可視化を行います。
#
# ## 参考
#
# *   オリジナルの手法[Nakahara+23]の論文：https://ieeexplore.ieee.org/abstract/document/10328596/
# *   OpenSTARLab Preprocessing (code): https://github.com/open-starlab/PreProcessing
# *   OpenSTARLab Preprocessing (SAR format doc): https://openstarlab.readthedocs.io/en/latest/Pre_Processing/Sports/SAR_data/index.html
# *   OpenSTARLab RLearn (code): https://github.com/open-starlab/RLearn
# *   OpenSTARLab RLearn (doc): https://openstarlab.readthedocs.io/en/latest/RLearn_Modeling/index.html
#
# ## クレジット
# *   Authors: Kenjiro Ide & Keisuke Fujii
# *   Affiliation: Nagoya University
# *   Last updated: 2026-4-23
# *   License: CC BY 4.0

# %% [markdown]
# 強化学習においてGPUが必要なため、
#
# ランタイム -> ランタイムのタイプを変更 -> T4 GPU
#
# としてデフォルトのCPUからGPUに変更してください。
#
# このノートブックで実行する手順は以下です。
#
# 1.  **環境構築**
#
# 2.  **FIFA World Cup 2022 データのダウンロード**
#
# 3.  **データの前処理**
#
# 4.  **データ分割とモデルの訓練**
#
# 5.  **Q値の可視化**

# %% [markdown]
# # 1.⚙️ 環境構築
#
#
# *   Pythonのバージョンを3.10へ変更
# *   Python3.10にpipをインストール
# *   venvで仮想環境を構築
# *   仮想環境のパスをシステムパスに設定
# *   仮想環境へopenstarlabのパッケージをインストール

# %%
# !python --version # Check python version
# Out:
# Python 3.12.13

# %%
# Install python 3.10
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils -y
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,608 kB]
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [90.8 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,293 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,995 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,913 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.2 MB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [61.6 kB]
# Hit:17 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.0 kB]
# Hit:20 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,245 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,245 kB]
# Get:23 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,601 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:27 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,998 kB]
# Fetched 41.9 MB in 3s (13.7 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.15).
# python3.10 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 128 not upgraded.

# %% [markdown]
# Pathがpython3.10になっているSelectionの番号を入力

# %%
# Set default python version to python 3.10
# 1. Install Python 3.10 + pip quietly
# !sudo apt-get update -qq > /dev/null 2>&1
# !sudo apt-get install -y -qq python3.10 python3.10-distutils python3.10-venv curl > /dev/null 2>&1
# !curl -sS https://bootstrap.pypa.io/get-pip.py | sudo python3.10 > /dev/null 2>&1

# 2. Set Python 3.10 as default quietly
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1 > /dev/null 2>&1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 2 > /dev/null 2>&1
# !sudo update-alternatives --set python3 /usr/bin/python3.10 > /dev/null 2>&1

# 3. Upgrade pip & install kernel quietly
# !python3 -m pip install --upgrade pip setuptools wheel ipykernel -q > /dev/null 2>&1
# !python3 -m ipykernel install --user --name=python310 --display-name "Python 3.10 (Colab)" > /dev/null 2>&1

# 4. Confirm python version 3.10.x
# !python --version
# Out:
# Python 3.10.12

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip --version
# Out:
# pip 26.1.1 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# Install pip module to python 3.10 environment
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.10 get-pip.py
# Out:
# --2026-05-06 20:23:35--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226394 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.12M  --.-KB/s    in 0.04s
#
# 2026-05-06 20:23:35 (47.7 MB/s) - ‘get-pip.py’ saved [2226394/2226394]
#
# Collecting pip
#   Using cached pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.1
#     Uninstalling pip-26.1.1:
#       Successfully uninstalled pip-26.1.1
# Successfully installed pip-26.1.1

# %%
# !pip --version
# Out:
# pip 26.1.1 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !apt-get install -y python3.10-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10-venv is already the newest version (3.10.12-1~22.04.15).
# 0 upgraded, 0 newly installed, 0 to remove and 125 not upgraded.

# %%
# !python -m venv openstarlab_env

# %%
# !/content/openstarlab_env/bin/python --version
# Out:
# Python 3.10.12

# %%
import os
import sys

venv_path = '/content/openstarlab_env'
python_version = "python3.10"
site_packages_path = os.path.join(venv_path, 'lib', python_version, 'site-packages')

if site_packages_path not in sys.path:
  sys.path.insert(0, site_packages_path)
  print(f"'{site_packages_path}' がシステムパスに追加されました。")
else:
  print("パスはすでに設定されています。")

# 現在のsys.pathの先頭が仮想環境になっているか確認
print("\n現在のsys.path[0]:", sys.path[0])
# Out:
# '/content/openstarlab_env/lib/python3.10/site-packages' がシステムパスに追加されました。
#
# 現在のsys.path[0]: /content/openstarlab_env/lib/python3.10/site-packages

# %%
# Install openstarlab module
# !./openstarlab_env/bin/pip install \
    "numpy==1.24.4" \
    "scipy==1.10.1" \
    "pandas" \
    "openstarlab-preprocessing==0.1.43" \
    "openstarlab-rlearn==0.1.32"
# Out:
# Collecting numpy==1.24.4
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 48.5 MB/s eta 0:00:00
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 47.6 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.8 MB/s eta 0:00:00
# Collecting openstarlab-preprocessing==0.1.43
#   Downloading openstarlab_preprocessing-0.1.43-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.8/170.8 KB 17.7 MB/s eta 0:00:00
# Collecting openstarlab-rlearn==0.1.32
#   Downloading openstarlab_rlearn-0.1.32-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 KB 16.4 MB/s eta 0:00:00
# Collecting matplotlib>=3.7.5
#   Downloading matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 98.2 MB/s eta 0:00:00
# Collecting gdown
#   Downloading gdown-6.0.0-py3-none-any.whl (18 kB)
# Collecting jsonlines>=3.1.0
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting pydantic>=2.9.0
#   Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 KB 5.9 MB/s eta 0:00:00
# Collecting datasets>=3.0.1
#   Downloading datasets-4.8.5-py3-none-any.whl (528 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 KB 65.8 MB/s eta 0:00:00
# Collecting ai2-tango
#   Downloading ai2_tango-1.3.2-py3-none-any.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 KB 42.2 MB/s eta 0:00:00
# Collecting statsbombpy>=0.0.1
#   Downloading statsbombpy-1.18.0-py3-none-any.whl (17 kB)
# Collecting chardet>=5.2.0
#   Downloading chardet-7.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (886 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.5/886.5 KB 78.5 MB/s eta 0:00:00
# Collecting shapely>=2.0.0
#   Downloading shapely-2.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 135.5 MB/s eta 0:00:00
# Collecting pyarrow<20.0.0,>=4.0.0
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 12.9 MB/s eta 0:00:00
# Collecting bidict>=0.22.1
#   Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 15.7 MB/s eta 0:00:00
# Collecting scikit-learn>=1.5.0
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 122.9 MB/s eta 0:00:00
# Collecting cloudpickle>=3.0.0
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Collecting importlib-metadata<=8.5,>=6.0
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Collecting tensorboardX>=2.6.0.0
#   Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 17.5 MB/s eta 0:00:00
# Collecting lightning-lite>=1.8.6
#   Downloading lightning_lite-1.8.6-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 KB 26.1 MB/s eta 0:00:00
# Collecting tensorboard>=2.18.0
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 141.1 MB/s eta 0:00:00
# Collecting pytorch-lightning>=2.4.0
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 KB 68.7 MB/s eta 0:00:00
# Collecting chardet>=5.2.0
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 KB 35.5 MB/s eta 0:00:00
# Collecting torchmetrics==1.4.0
#   Downloading torchmetrics-1.4.0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 KB 75.6 MB/s eta 0:00:00
# Collecting mlflow>=2.16.0
#   Downloading mlflow-3.12.0-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 119.2 MB/s eta 0:00:00
# Collecting matplotsoccer>=0.0.8
#   Downloading matplotsoccer-0.0.8.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib>=3.7.5
#   Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 106.6 MB/s eta 0:00:00
# Collecting opencv-python>=4.10.0
#   Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.1 MB/s eta 0:00:00
# Collecting packaging>=23.0
#   Downloading packaging-26.2-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 KB 14.1 MB/s eta 0:00:00
# Collecting japanize-matplotlib==1.1.3
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 67.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fire==0.5.0
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting dill
#   Downloading dill-0.4.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 KB 20.1 MB/s eta 0:00:00
# Collecting GitPython<4.0,>=3.0
#   Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 KB 35.1 MB/s eta 0:00:00
# Collecting click<8.1.4,>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 19.7 MB/s eta 0:00:00
# Collecting pytz
#   Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 KB 55.4 MB/s eta 0:00:00
# Collecting cached-path<2.0,>=1.0
#   Downloading cached_path-1.8.10-py3-none-any.whl (37 kB)
# Collecting filelock<4.0,>=3.4
#   Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Collecting rich<14.0,>=12.3
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 KB 28.1 MB/s eta 0:00:00
# Collecting click-help-colors<0.10,>=0.9.1
#   Downloading click_help_colors-0.9.4-py3-none-any.whl (6.4 kB)
# Collecting glob2>=0.7
#   Downloading glob2-0.7.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting more-itertools<10.0,>=8.0
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 10.8 MB/s eta 0:00:00
# Collecting petname<3.0,>=2.6
#   Downloading petname-2.9-py3-none-any.whl (14 kB)
# Collecting xxhash
#   Downloading xxhash-3.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.3/193.3 KB 25.5 MB/s eta 0:00:00
# Collecting PyYAML<7.0,>=5.4.1
#   Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 KB 47.7 MB/s eta 0:00:00
# Collecting rjsonnet>=0.5.0
#   Downloading rjsonnet-0.5.6-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.5 MB/s eta 0:00:00
# Collecting six
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting termcolor
#   Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 KB 23.7 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 134.4 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 129.0 MB/s eta 0:00:00
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 42.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 46.0 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.8.0
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Collecting torch>=1.10.0
#   Downloading torch-2.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (530.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.6/530.6 MB 1.7 MB/s eta 0:00:00
# Collecting pretty-errors==1.2.25
#   Downloading pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 KB 55.0 MB/s eta 0:00:00
# Collecting multiprocess<0.70.20
#   Downloading multiprocess-0.70.19-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 26.8 MB/s eta 0:00:00
# Collecting requests>=2.32.2
#   Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 14.5 MB/s eta 0:00:00
# Collecting fsspec[http]<=2026.2.0,>=2023.1.0
#   Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 KB 37.1 MB/s eta 0:00:00
# Collecting httpx<1.0.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 15.8 MB/s eta 0:00:00
# Collecting datasets>=3.0.1
#   Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 KB 68.7 MB/s eta 0:00:00
#   Downloading datasets-4.8.3-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 KB 68.5 MB/s eta 0:00:00
#   Downloading datasets-4.8.2-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 KB 56.9 MB/s eta 0:00:00
#   Downloading datasets-4.8.1-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 KB 64.6 MB/s eta 0:00:00
#   Downloading datasets-4.8.0-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 KB 65.1 MB/s eta 0:00:00
#   Downloading datasets-4.7.0-py3-none-any.whl (527 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.5/527.5 KB 56.9 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 KB 24.4 MB/s eta 0:00:00
# Collecting datasets>=3.0.1
#   Downloading datasets-4.6.1-py3-none-any.whl (520 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 KB 69.0 MB/s eta 0:00:00
#   Downloading datasets-4.6.0-py3-none-any.whl (520 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 KB 66.2 MB/s eta 0:00:00
#   Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 KB 65.5 MB/s eta 0:00:00
# Collecting huggingface-hub<2.0,>=0.25.0
#   Downloading huggingface_hub-1.14.0-py3-none-any.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.5/661.5 KB 68.5 MB/s eta 0:00:00
# Collecting datasets>=3.0.1
#   Downloading datasets-4.4.2-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.3/512.3 KB 66.5 MB/s eta 0:00:00
#   Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 KB 45.3 MB/s eta 0:00:00
#   Downloading datasets-4.4.0-py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.5/511.5 KB 55.7 MB/s eta 0:00:00
#   Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 KB 47.3 MB/s eta 0:00:00
# Collecting fsspec[http]<=2025.9.0,>=2023.1.0
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 KB 32.6 MB/s eta 0:00:00
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 KB 25.9 MB/s eta 0:00:00
# Collecting datasets>=3.0.1
#   Downloading datasets-4.2.0-py3-none-any.whl (506 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.3/506.3 KB 61.6 MB/s eta 0:00:00
#   Downloading datasets-4.1.1-py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.6/503.6 KB 45.4 MB/s eta 0:00:00
#   Downloading datasets-4.1.0-py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.4/503.4 KB 52.7 MB/s eta 0:00:00
#   Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 KB 55.4 MB/s eta 0:00:00
# Collecting fsspec[http]<=2025.3.0,>=2023.1.0
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 KB 33.2 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 KB 20.6 MB/s eta 0:00:00
# Collecting zipp>=3.20
#   Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Collecting attrs>=19.2.0
#   Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 KB 11.6 MB/s eta 0:00:00
# Collecting typing-extensions>=4.0.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 8.8 MB/s eta 0:00:00
# Collecting huey<3,>=2.5.4
#   Downloading huey-2.6.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 KB 15.4 MB/s eta 0:00:00
# Collecting Flask-CORS<7
#   Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Collecting mlflow-tracing==3.12.0
#   Downloading mlflow_tracing-3.12.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 111.2 MB/s eta 0:00:00
# Collecting aiohttp<4
#   Downloading aiohttp-3.13.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 100.5 MB/s eta 0:00:00
# Collecting mlflow-skinny==3.12.0
#   Downloading mlflow_skinny-3.12.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 119.3 MB/s eta 0:00:00
# Collecting sqlalchemy<3,>=1.4.0
#   Downloading sqlalchemy-2.0.49-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 90.1 MB/s eta 0:00:00
# Collecting gunicorn<26
#   Downloading gunicorn-25.3.0-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 KB 39.6 MB/s eta 0:00:00
# Collecting Flask<4
#   Downloading flask-3.1.3-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 KB 21.4 MB/s eta 0:00:00
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 KB 29.6 MB/s eta 0:00:00
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 KB 22.4 MB/s eta 0:00:00
# Collecting skops<1
#   Downloading skops-0.14.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 KB 25.6 MB/s eta 0:00:00
# Collecting cryptography<47,>=43.0.0
#   Downloading cryptography-46.0.7-cp38-abi3-manylinux_2_34_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 139.7 MB/s eta 0:00:00
# Collecting alembic!=1.10.0,<2
#   Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 KB 46.8 MB/s eta 0:00:00
# Collecting starlette<1
#   Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 KB 11.0 MB/s eta 0:00:00
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 KB 23.1 MB/s eta 0:00:00
# Collecting opentelemetry-proto<3,>=1.9.0
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 KB 13.6 MB/s eta 0:00:00
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 KB 5.9 MB/s eta 0:00:00
# Collecting python-dotenv<2,>=0.19.0
#   Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 KB 9.1 MB/s eta 0:00:00
# Collecting cachetools<8,>=5.0.0
#   Downloading cachetools-7.1.1-py3-none-any.whl (16 kB)
# Collecting protobuf<8,>=3.12.0
#   Downloading protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 KB 45.4 MB/s eta 0:00:00
# Collecting uvicorn<1
#   Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 KB 10.5 MB/s eta 0:00:00
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.106.0-py3-none-any.whl (879 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.5/879.5 KB 81.3 MB/s eta 0:00:00
# Collecting fastapi<1
#   Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 KB 21.4 MB/s eta 0:00:00
# Collecting opencv-python>=4.10.0
#   Downloading opencv_python-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.2 MB/s eta 0:00:00
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 10.7 MB/s eta 0:00:00
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 11.5 MB/s eta 0:00:00
# Collecting pydantic-core==2.46.4
#   Downloading pydantic_core-2.46.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.8 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 KB 45.1 MB/s eta 0:00:00
# Collecting requests-cache
#   Downloading requests_cache-1.3.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 KB 9.8 MB/s eta 0:00:00
# Collecting inflect
#   Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 KB 32.7 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 KB 13.6 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 93.3 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.80.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 118.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in ./openstarlab_env/lib/python3.10/site-packages (from tensorboard>=2.18.0->openstarlab-rlearn==0.1.32) (68.1.2)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 KB 28.9 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 KB 20.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.23.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 KB 20.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.5/219.5 KB 36.4 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.9/196.9 KB 33.9 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 KB 41.0 MB/s eta 0:00:00
# Collecting Mako
#   Downloading mako-1.3.12-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 14.6 MB/s eta 0:00:00
# Collecting tomli
#   Downloading tomli-2.4.1-py3-none-any.whl (14 kB)
# Collecting google-cloud-storage<4.0,>=1.32.0
#   Downloading google_cloud_storage-3.10.1-py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.5/324.5 KB 44.0 MB/s eta 0:00:00
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.43.5-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 KB 23.1 MB/s eta 0:00:00
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 KB 37.5 MB/s eta 0:00:00
# Collecting urllib3>=1.26.0
#   Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 KB 26.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting markupsafe>=2.1.1
#   Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Collecting jinja2>=3.1.2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 26.5 MB/s eta 0:00:00
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 12.7 MB/s eta 0:00:00
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 KB 38.9 MB/s eta 0:00:00
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Collecting typer>=0.20.0
#   Downloading typer-0.25.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 KB 12.4 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.4.3
#   Downloading hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 122.8 MB/s eta 0:00:00
# Collecting certifi>=2023.5.7
#   Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 KB 26.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.13-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 KB 14.9 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.9/216.9 KB 37.3 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.1.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 KB 18.2 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.9 MB/s eta 0:00:00
# Collecting prettytable>=3.9
#   Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Collecting skops<1
#   Downloading skops-0.13.0-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 KB 25.0 MB/s eta 0:00:00
#   Downloading skops-0.12.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 KB 28.9 MB/s eta 0:00:00
#   Downloading skops-0.11.0-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 KB 24.7 MB/s eta 0:00:00
# Collecting tabulate>=0.8.8
#   Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Collecting greenlet>=1
#   Downloading greenlet-3.5.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.4/613.4 KB 67.3 MB/s eta 0:00:00
# Collecting cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 11.6 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 132.0 MB/s eta 0:00:00
# Collecting cuda-bindings<14,>=13.0.3
#   Downloading cuda_bindings-13.2.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 117.8 MB/s eta 0:00:00
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 92.0 MB/s eta 0:00:00
# Collecting nvidia-cusparselt-cu13==0.8.0
#   Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 6.8 MB/s eta 0:00:00
# Collecting triton==3.6.0
#   Downloading triton-3.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.1/188.1 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu13==2.28.9
#   Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu13==9.19.0.56
#   Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 4.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc==13.0.88.*
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 9.1 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink==13.0.88.*
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 16.0 MB/s eta 0:00:00
# Collecting nvidia-nvtx==13.0.85.*
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 KB 21.7 MB/s eta 0:00:00
# Collecting nvidia-cufile==1.15.1.6.*
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.3 MB/s eta 0:00:00
# Collecting nvidia-curand==10.4.0.35.*
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 11.4 MB/s eta 0:00:00
# Collecting nvidia-cufft==12.0.0.61.*
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse==12.6.3.3.*
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver==12.0.4.66.*
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-cublas==13.1.0.3.*
#   Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime==13.0.96.*
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 89.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti==13.0.85.*
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 88.6 MB/s eta 0:00:00
# Collecting soupsieve>=1.6.1
#   Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Collecting typeguard>=4.0.1
#   Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Collecting cattrs>=22.2
#   Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 15.0 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.9.6-py3-none-any.whl (21 kB)
# Collecting url-normalize>=2.0
#   Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.18.0,>=0.17.0
#   Downloading s3transfer-0.17.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 18.5 MB/s eta 0:00:00
# Collecting botocore<1.44.0,>=1.43.5
#   Downloading botocore-1.43.5-py3-none-any.whl (15.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 78.3 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.1.1
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting pycparser
#   Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 KB 9.2 MB/s eta 0:00:00
# Collecting cuda-pathfinder~=1.1
#   Downloading cuda_pathfinder-1.5.4-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 KB 9.6 MB/s eta 0:00:00
# Collecting protobuf<8,>=3.12.0
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 KB 46.1 MB/s eta 0:00:00
# Collecting google-auth~=2.0
#   Downloading google_auth-2.50.0-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 KB 40.7 MB/s eta 0:00:00
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Collecting google-api-core<3.0.0,>=2.27.0
#   Downloading google_api_core-2.30.3-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.3/173.3 KB 33.1 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0.0,>=2.4.2
#   Downloading google_cloud_core-2.5.1-py3-none-any.whl (29 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3
#   Downloading google_crc32c-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2
#   Downloading google_resumable_media-2.8.2-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 KB 18.1 MB/s eta 0:00:00
# Collecting anyio
#   Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 KB 22.7 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 16.8 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting opentelemetry-semantic-conventions==0.62b1
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 KB 25.4 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 60.1 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting typer>=0.20.0
#   Downloading typer-0.25.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 KB 11.5 MB/s eta 0:00:00
#   Downloading typer-0.24.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 KB 10.3 MB/s eta 0:00:00
#   Downloading typer-0.24.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 KB 11.9 MB/s eta 0:00:00
#   Downloading typer-0.24.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 KB 11.1 MB/s eta 0:00:00
#   Downloading typer-0.23.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 KB 9.6 MB/s eta 0:00:00
#   Downloading typer-0.23.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 KB 12.5 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.27.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 7.4 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0.0,>=1.63.2
#   Downloading googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 KB 52.1 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 35.6 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 KB 18.0 MB/s eta 0:00:00
# Using legacy 'setup.py install' for fire, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for japanize-matplotlib, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for matplotsoccer, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for glob2, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for sqlitedict, since package 'wheel' is not installed.
# Installing collected packages: sqlitedict, rjsonnet, pytz, petname, nvidia-cusparselt-cu13, mpmath, matplotsoccer, huey, glob2, cuda-toolkit, zipp, xxhash, urllib3, tzdata, typing-extensions, triton, tqdm, tomli, threadpoolctl, termcolor, tensorboard-data-server, tabulate, sympy, sqlparse, soupsieve, smmap, six, shellingham, PyYAML, python-dotenv, PySocks, pyparsing, pygments, pycparser, pyasn1, pyarrow, protobuf, propcache, platformdirs, pillow, packaging, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, numpy, networkx, more-itertools, mdurl, markupsafe, markdown, kiwisolver, joblib, jmespath, itsdangerous, idna, hf-xet, h11, greenlet, graphql-core, google-crc32c, fsspec, frozenlist, fonttools, filelock, dill, cycler, cuda-pathfinder, colorama, cloudpickle, click, charset_normalizer, chardet, certifi, cachetools, blinker, bidict, base58, attrs, async-timeout, annotated-types, annotated-doc, aiohappyeyeballs, absl-py, werkzeug, uvicorn, url-normalize, typing-inspection, typeguard, tensorboardX, sqlalchemy, shapely, scipy, requests, python-dateutil, pydantic-core, pyasn1-modules, proto-plus, pretty-errors, opentelemetry-proto, opencv-python, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, multiprocess, multidict, markdown-it-py, Mako, lightning-utilities, jsonlines, jinja2, importlib-metadata, httpcore, gunicorn, grpcio, graphql-relay, googleapis-common-protos, google-resumable-media, gitdb, fire, exceptiongroup, cuda-bindings, contourpy, click-help-colors, cffi, beautifulsoup4, aiosignal, yarl, tensorboard, scikit-learn, rich, pydantic, pandas, opentelemetry-api, nvidia-cusolver, matplotlib, inflect, graphene, GitPython, Flask, docker, cryptography, cattrs, botocore, anyio, alembic, typer, starlette, s3transfer, requests-cache, opentelemetry-semantic-conventions, japanize-matplotlib, httpx, google-auth, gdown, Flask-CORS, aiohttp, torch, statsbombpy, opentelemetry-sdk, huggingface-hub, google-api-core, fastapi, databricks-sdk, boto3, torchmetrics, skops, mlflow-tracing, mlflow-skinny, lightning-lite, google-cloud-core, datasets, pytorch-lightning, mlflow, google-cloud-storage, cached-path, ai2-tango, openstarlab-rlearn, openstarlab-preprocessing
#   Running setup.py install for sqlitedict ... done
#   Running setup.py install for matplotsoccer ... done
#   Running setup.py install for glob2 ... done
#   Running setup.py install for fire ... done
#   Running setup.py install for japanize-matplotlib ... done
# Successfully installed Flask-3.1.3 Flask-CORS-6.0.2 GitPython-3.1.50 Mako-1.3.12 PySocks-1.7.1 PyYAML-6.0.3 absl-py-2.4.0 ai2-tango-1.3.2 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 alembic-1.18.4 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.13.0 async-timeout-5.0.1 attrs-26.1.0 base58-2.1.1 beautifulsoup4-4.14.3 bidict-0.23.1 blinker-1.9.0 boto3-1.43.5 botocore-1.43.5 cached-path-1.8.10 cachetools-7.1.1 cattrs-26.1.0 certifi-2026.4.22 cffi-2.0.0 chardet-5.2.0 charset_normalizer-3.4.7 click-8.1.3 click-help-colors-0.9.4 cloudpickle-3.1.2 colorama-0.4.6 contourpy-1.3.2 cryptography-46.0.7 cuda-bindings-13.2.0 cuda-pathfinder-1.5.4 cuda-toolkit-13.0.2 cycler-0.12.1 databricks-sdk-0.106.0 datasets-4.0.0 dill-0.3.8 docker-7.1.0 exceptiongroup-1.3.1 fastapi-0.136.1 filelock-3.29.0 fire-0.5.0 fonttools-4.62.1 frozenlist-1.8.0 fsspec-2025.3.0 gdown-6.0.0 gitdb-4.0.12 glob2-0.7 google-api-core-2.30.3 google-auth-2.50.0 google-cloud-core-2.5.1 google-cloud-storage-3.10.1 google-crc32c-1.8.0 google-resumable-media-2.8.2 googleapis-common-protos-1.74.0 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 greenlet-3.5.0 grpcio-1.80.0 gunicorn-25.3.0 h11-0.16.0 hf-xet-1.5.0 httpcore-1.0.9 httpx-0.28.1 huey-2.6.0 huggingface-hub-1.14.0 idna-3.13 importlib-metadata-8.5.0 inflect-7.5.0 itsdangerous-2.2.0 japanize-matplotlib-1.1.3 jinja2-3.1.6 jmespath-1.1.0 joblib-1.5.3 jsonlines-4.0.0 kiwisolver-1.5.0 lightning-lite-1.8.6 lightning-utilities-0.15.3 markdown-3.10.2 markdown-it-py-4.1.0 markupsafe-3.0.3 matplotlib-3.9.0 matplotsoccer-0.0.8 mdurl-0.1.2 mlflow-3.12.0 mlflow-skinny-3.12.0 mlflow-tracing-3.12.0 more-itertools-9.1.0 mpmath-1.3.0 multidict-6.7.1 multiprocess-0.70.16 networkx-3.4.2 numpy-1.24.4 nvidia-cublas-13.1.0.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.0 nvidia-nccl-cu13-2.28.9 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 opencv-python-4.11.0.86 openstarlab-preprocessing-0.1.43 openstarlab-rlearn-0.1.32 opentelemetry-api-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 packaging-26.2 pandas-2.3.3 petname-2.9 pillow-12.2.0 platformdirs-4.9.6 pretty-errors-1.2.25 propcache-0.4.1 proto-plus-1.27.2 protobuf-6.33.6 pyarrow-19.0.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 pygments-2.20.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 python-dotenv-1.2.2 pytorch-lightning-2.6.1 pytz-2026.2 requests-2.33.1 requests-cache-1.3.1 rich-13.9.4 rjsonnet-0.5.6 s3transfer-0.17.0 scikit-learn-1.7.2 scipy-1.10.1 shapely-2.1.2 shellingham-1.5.4 six-1.17.0 skops-0.11.0 smmap-5.0.3 soupsieve-2.8.3 sqlalchemy-2.0.49 sqlitedict-2.1.0 sqlparse-0.5.5 starlette-0.52.1 statsbombpy-1.18.0 sympy-1.14.0 tabulate-0.10.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorboardX-2.6.5 termcolor-3.3.0 threadpoolctl-3.6.0 tomli-2.4.1 torch-2.11.0 torchmetrics-1.4.0 tqdm-4.67.3 triton-3.6.0 typeguard-4.5.1 typer-0.23.1 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2026.2 url-normalize-3.0.0 urllib3-2.6.3 uvicorn-0.46.0 werkzeug-3.1.8 xxhash-3.7.0 yarl-1.23.0 zipp-3.23.1

# %% [markdown]
# パッケージが正しくインストールされているか確認

# %%
import sys

# 1. Pythonがライブラリを探しに行くパスのリストを表示
print("--- sys.path ---")
for path in sys.path:
    print(path)

# 2. openstarlabが実際にインストールされている場所を確認
print("\n--- pip show openstarlab-preprocessing ---")
# !/content/openstarlab_env/bin/python -m pip show openstarlab-preprocessing

print("\n--- pip show openstarlab-rlearn ---")
# !/content/openstarlab_env/bin/python -m pip show openstarlab-rlearn
# Out:
# --- sys.path ---
# /content/openstarlab_env/lib/python3.10/site-packages
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython
#
# --- pip show openstarlab-preprocessing ---
# Name: openstarlab_preprocessing
# Version: 0.1.43
# Summary: openstarlab preprocessing package
# Home-page:
# Author:
# Author-email: Calvin Yeung <yeung.chikwong@g.sp.m.is.nagoya-u.ac.jp>
# License: Apache License 2.0
# Location: /content/openstarlab_env/lib/python3.10/site-packages
# Requires: ai2-tango, bidict, chardet, datasets, gdown, jsonlines, matplotlib, numpy, pandas, pyarrow, pydantic, scipy, shapely, statsbombpy, tqdm
# Required-by:
#
# --- pip show openstarlab-rlearn ---
# Name: openstarlab_rlearn
# Version: 0.1.32
# Summary: openstarlab rlearn modeliing package
# Home-page:
# Author:
# Author-email: Kenjiro Ide <ide.kenjirog@g.sp.m.is.nagoya-u.ac.jp>
# License: Apache License 2.0
# Location: /content/openstarlab_env/lib/python3.10/site-packages
# Requires: ai2-tango, bidict, chardet, cloudpickle, datasets, fire, importlib-metadata, japanize-matplotlib, jsonlines, lightning-lite, matplotlib, matplotsoccer, mlflow, numpy, opencv-python, packaging, pandas, pyarrow, pydantic, pytorch-lightning, scikit-learn, scipy, tensorboard, tensorboardX, torchmetrics, tqdm
# Required-by:

# %%
# %%writefile check_library.py

# --- Matplotlibバックエンド設定（最重要） ---
# pyplotや、それを内部で使うライブラリ(preprocessing)をインポートする『前』に必ず記述します。
import matplotlib
matplotlib.use('Agg')
# -----------------------------------------

import sys
print("--- Python Script Start ---")
# 実行しているPythonのバージョンを確認
print(f"Executing with Python Version: {sys.version}")

try:
    # 正しいインポート文を記述
    import preprocessing
    import rlearn
    import numpy as np

    print("\n✅✅✅ openstarlab and numpy libraries were successfully imported!")
    print(f"NumPy Version: {np.__version__}")

except ImportError as e:
    print(f"\n❌❌❌ Import failed: {e}")

print("--- Python Script End ---")
# Out:
# Writing check_library.py

# %%
# Unset the environment variable and then run the script in one command
! unset MPLBACKEND && /content/openstarlab_env/bin/python check_library.py
# Out:
# --- Python Script Start ---
# Executing with Python Version: 3.10.12 (main, Mar  3 2026, 11:56:32) [GCC 11.4.0]
#
# ✅✅✅ openstarlab and numpy libraries were successfully imported!
# NumPy Version: 1.24.4
# --- Python Script End ---

# %% [markdown]
# # 2.📥 FIFA World Cup 2022のデータをダウンロード

# %% [markdown]
# PFF FCにより提供されたFIFA World Cup 2022のデータを使用します（
# イベントデータ、トラッキングデータ、メタデータ、ロスターデータが含まれます）。
#
#
# World Cup 2022データセットは、申請フォーム（https://www.blog.fc.pff.com/blog/pff-fc-release-2022-world-cup-data ）経由で無償提供されるものですが、公開ページおよび入手時点の通知において、2025年11月時点において明確な利用規約（再配布可否や商用利用の可否など）は提示されていませんでした。そのため、本書では当該データの再配布や同梱は行わず、各自で配布元のフォームから入手していただく方針とします。本Notebookは、手動でデータを配置する前提で提供しますので、入手後に各自の環境で設定して実行してください（利用範囲や掲示義務は将来変更される可能性があるため、最新の方針については配布元の案内を必ず確認し、不明点は配布元に問い合わせることを推奨します。なお、後日あらためて利用条件が提示された場合には、その条件に従って運用してください）。

# %%
# gdownライブラリをインストールします
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-6.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting requests[socks] (from gdown)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting tqdm (from gdown)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.15.0)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown)
#   Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests[socks]->gdown)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests[socks]->gdown)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading gdown-6.0.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: urllib3, tqdm, soupsieve, PySocks, idna, filelock, charset_normalizer, certifi, requests, beautifulsoup4, gdown
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [gdown]
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.14.3 certifi-2026.4.22 charset_normalizer-3.4.7 filelock-3.29.0 gdown-6.0.0 idna-3.13 requests-2.33.1 soupsieve-2.8.3 tqdm-4.67.3 urllib3-2.6.3

# %%
# 必要なフォルダーを作成

# !mkdir -p /content/data

# !mkdir -p "/content/data/Rosters"
# !mkdir -p "/content/data/Tracking Data"
# !mkdir -p "/content/data/Event Data"
# !mkdir -p "/content/data/Metadata"

# %% [markdown]
# ダウンロードしたイベントデータ（Event Data）、トラッキングデータ（Tracking Data）、メタデータ（Metadata）、ロスターデータ（Rosters）のフォルダの中にあるファイルを /content/data にセットしてください。あと、players.csvも /content/data  にセットする必要があります。
#
# 今回は、['3812', '3813', '3814', '3815', '3816']のファイルをそれぞれ4つの元フォルダから、左のファイルリストの /content/dataの各フォルダにドラッグ＆ドロップしてください。全試合をアップロードしようとすると、この方法では時間が掛かりそうなので、Google drive経由か、Google Colabを使わない方法を推奨します。

# %%
# ファイルを入れたあと、/content/data ディレクトリの中身を確認します
# !ls -F /content/data/
# Out:
#  competitions.csv   Metadata/	  Rosters/
# 'Event Data'/	    players.csv  'Tracking Data'/

# %%
# Google Driveの共有リンクからファイルをダウンロードします
# !gdown '1qzxkPE8j8AwapokYeOCCZb_Wc5j9ingE' -O 'config.zip'

# !unzip config.zip

# !gdown '1eFmKJBO-I3TToS0SA2AUClsV_hj4cRCZ' -O 'EPV_grid.csv'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qzxkPE8j8AwapokYeOCCZb_Wc5j9ingE
# To: /content/config.zip
# 100% 2.92k/2.92k [00:00<00:00, 12.7MB/s]
# Archive:  config.zip
#    creating: config/
#   inflating: config/exp_fifawc2022.json
#   inflating: config/preprocessing_fifawc2022.json
# Downloading...
# From: https://drive.google.com/uc?id=1eFmKJBO-I3TToS0SA2AUClsV_hj4cRCZ
# To: /content/EPV_grid.csv
# 100% 11.2k/11.2k [00:00<00:00, 43.1MB/s]

# %% [markdown]
# # 3.✂️ openstarlab-preprocessingで前処理

# %% [markdown]
# ## 前処理

# %%
# %%writefile preprocessing_fifawc2022.py

from pathlib import Path
from preprocessing import SAR_data

# Step 2: Define your data path as a Path object
data_directory = Path("/content/data")
config_path = Path("/content/config/preprocessing_fifawc2022.json")

# Step 3: Pass the Path object to the class
SAR_data(
    data_provider="fifawc",
    data_path=data_directory,
    state_def="PVS",
    config_path=config_path,
    preprocess_method="SAR",
    match_id=3812,
    max_workers=1
).preprocess_data()

SAR_data(
    data_provider="fifawc",
    data_path=data_directory,
    state_def="PVS",
    config_path=config_path,
    preprocess_method="SAR",
    match_id=3813,
    max_workers=1
).preprocess_data()

SAR_data(
    data_provider="fifawc",
    data_path=data_directory,
    state_def="PVS",
    config_path=config_path,
    preprocess_method="SAR",
    match_id=3814,
    max_workers=1
).preprocess_data()

print("\n✅ Preprocessing completed successfully!")
# Out:
# Writing preprocessing_fifawc2022.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python preprocessing_fifawc2022.py

# %%
# %%writefile split_data_fifawc2022.py

from rlearn import RLearn_Model
from pathlib import Path

# デバッグのために、RLearn_Modelに渡される前にゲームIDが検出されるか確認します。
input_data_path = Path("/content/data/fifawc/preprocess_data/")

game_ids = []
if input_data_path.exists():
    for item in input_data_path.iterdir():
        if item.is_dir() and item.name.isdigit():
            game_ids.append(item.name)

print(f"Detected game IDs: {game_ids}")

# もしゲームIDが検出されていなければ、ここで処理を停止できます。
if not game_ids:
    print("エラー: 検出されたゲームIDがありません。データを分割できません。")
else:
    RLearn_Model(
        state_def="PVS",
        input_path=str(input_data_path),
        output_path="/content/data/fifawc/preprocess_data/split/",
    ).run_rlearn(
        run_split_train_test=True,
        run_preprocess_observation=False,
        run_train_and_test=False,
        run_visualize_data=False
    )

    print("\n✅ Spliting data completed successfully!")
# Out:
# Writing split_data_fifawc2022.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python split_data_fifawc2022.py

# %% [markdown]
# ## 4. openstarlab-rlearnでデータを分割し、observationを作成し、学習と推論を実行します。

# %%
# %%writefile observation_fifawc2022.py

from pathlib import Path
from rlearn import RLearn_Model
from rlearn.sports.main_class import PreprocessObservationConfig

config_path = Path("/content/config/preprocessing_fifawc2022.json")

# splitデータのパスを更新
split_data_base_path = "/content/data/fifawc/preprocess_data/split/"

RLearn_Model(
    state_def="PVS",
    config=config_path,
    num_process=1,
    input_path=split_data_base_path + "train",
    output_path="/content/data/fifawc/observation_data/split/train",
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=True,
    run_train_and_test=False,
    run_visualize_data=False,
    preprocess_config=PreprocessObservationConfig(batch_size=8)
)

RLearn_Model(
    state_def="PVS",
    config=config_path,
    num_process=1,
    input_path=split_data_base_path + "validation",
    output_path="/content/data/fifawc/observation_data/split/validation",
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=True,
    run_train_and_test=False,
    run_visualize_data=False,
    preprocess_config=PreprocessObservationConfig(batch_size=8)
)

RLearn_Model(
    state_def="PVS",
    config=config_path,
    num_process=1,
    input_path=split_data_base_path + "test",
    output_path="/content/data/fifawc/observation_data/split/test",
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=True,
    run_train_and_test=False,
    run_visualize_data=False,
    preprocess_config=PreprocessObservationConfig(batch_size=8)
)

print("\n✅ Creating Observation data completed successfully!")
# Out:
# Writing observation_fifawc2022.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python observation_fifawc2022.py

# %%
import json

config_path = "/content/config/exp_fifawc2022.json"

with open(config_path, 'r') as f:
    config_data = json.load(f)

print(config_data)

# Modify some values in the config_data dictionary
config_data['dataset']['train_filename'] = '/content/data/fifawc/observation_data/split/train'
config_data['dataset']['valid_filename'] = '/content/data/fifawc/observation_data/split/validation'
config_data['dataset']['test_filename'] = '/content/data/fifawc/observation_data/split/test'

print(f"config: {config_data["dataset"]["test_filename"]}")

# changed learning rate and max epoch
print(f"max epochs: {config_data['max_epochs']}, learning rate: {config_data['model']['optimizer']['lr']}")

# Modify some values in the config_data dictionary
config_data['max_epochs'] = 1  # Example: Change max_epochs to 30
config_data['model']['optimizer']['lr'] = 0.01 # Example: Change learning rate to 0.001
config_data['datamodule']['type'] = 'rl_attacker' # Fix the datamodule type

# You can modify other values as needed
# config_data['datamodule']['batch_size'] = 128

# Print the modified values to confirm
print(f"max epochs: {config_data['max_epochs']}, learning rate: {config_data['model']['optimizer']['lr']}")
print(f"datamodule type: {config_data['datamodule']['type']}")
# Out:
# {'dataset': {'train_filename': '/content/data/fifawc/observation_data/split/train', 'valid_filename': '/content/data/fifawc/observation_data/split/validation', 'test_filename': '/content/data/fifawc/observation_data/split/test', 'preprocess_config': {'state_action_tokenizer': {'type': 'action_only', 'action2id': {'idle': 0, 'right': 1, 'up_right': 2, 'up': 3, 'up_left': 4, 'left': 5, 'down_left': 6, 'down': 7, 'down_right': 8, 'shot': 9, 'dribble': 10, 'through_pass': 11, 'pass': 12, 'cross': 13, 'defensive_action': 14}, 'origin_pos': 'center', 'special_tokens': ['[PAD]']}, 'num_workers': 8, 'preprocess_batch_size': 32}}, 'datamodule': {'type': 'jleague_rl_attacker', 'state_action_tokenizer': {'type': 'action_only', 'action2id': {'idle': 0, 'right': 1, 'up_right': 2, 'up': 3, 'up_left': 4, 'left': 5, 'down_left': 6, 'down': 7, 'down_right': 8, 'shot': 9, 'dribble': 10, 'through_pass': 11, 'pass': 12, 'cross': 13, 'defensive_action': 14}, 'origin_pos': 'center', 'special_tokens': ['[PAD]']}, 'num_workers': 8, 'batch_size': 256}, 'model': {'type': 'sarsa_attacker', 'observation_dim': 92, 'sequence_encoder': {'type': 'gru', 'input_size': 64, 'hidden_size': 64, 'num_layers': 1, 'bias': True, 'dropout': 0.0, 'bidirectional': False}, 'vocab_size': 16, 'optimizer': {'type': 'torch::Adam', 'lr': 0.001, 'weight_decay': 1e-05}, 'gamma': 1.0, 'lambda_': 0.0001, 'lambda2_': 0.005}, 'class_weight_fn': {'type': 'exponential', 'cache_path': '/content/data/weight/sarsa_attacker/fifawc/observation_data/exponential_beta0.9.pt', 'beta': 0.9}, 'enable_onball_offball_metrics': False, 'max_epochs': 30, 'val_check_interval': 0.5, 'accumulate_grad_batches': 1, 'offball_action_idx': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'onball_action_idx': [9, 10, 11, 12, 13], 'defensive_action_idx': [14]}
# config: /content/data/fifawc/observation_data/split/test
# max epochs: 30, learning rate: 0.001
# max epochs: 1, learning rate: 0.01
# datamodule type: rl_attacker

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python train_fifawc2022.py
# Out:
# /content/openstarlab_env/bin/python: can't open file '/content/train_fifawc2022.py': [Errno 2] No such file or directory

# %%
with open(config_path, 'w') as f:
    json.dump(config_data, f, indent=4)

print(f"Modified config saved to {config_path}")
# Out:
# Modified config saved to /content/config/exp_fifawc2022.json

# %% [markdown]
# GPUに変更するときに、ランタイムがリセットされるため、作成したファイルをzip圧縮してGoogle Driveへ保存

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# config, data, openstarlab_env フォルダと、直下にある python ファイルなどをまとめて固める
# !zip -r /content/drive/MyDrive/colab_data_backup.zip data config openstarlab_env *.py *.csv
# Out:
# zip error: Interrupted (aborting)

# %% [markdown]
# ## 学習・評価
# ここから強化学習のためにGPUを使用するため、CPUからGPUに変更する必要がある。
#
# 手順
#
# ランタイム -> ランタイムのタイプを変更 -> T4 GPU

# %% [markdown]
# Google DriveからGoogle Colabへフォルダをアップロード

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/colab_data_backup.zip /content/

# %%
# !unzip /content/colab_data_backup.zip -d /content/
# Out:
# Archive:  /content/colab_data_backup.zip
# replace /content/data/Tracking Data/3815.jsonl.bz2? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#    creating: /content/data/fifawc/clean_data/3813/
#   inflating: /content/data/fifawc/clean_data/3813/events.csv
#   inflating: /content/data/fifawc/clean_data/3813/player_info.csv
#   inflating: /content/data/fifawc/clean_data/3813/frames.jsonl
#   inflating: /content/data/fifawc/clean_data/3813/tracking.jsonl
#    creating: /content/data/fifawc/clean_data/3814/
#   inflating: /content/data/fifawc/clean_data/3814/events.csv
#   inflating: /content/data/fifawc/clean_data/3814/player_info.csv
#   inflating: /content/data/fifawc/clean_data/3814/frames.jsonl
#   inflating: /content/data/fifawc/clean_data/3814/tracking.jsonl
#    creating: /content/data/fifawc/preprocess_data/split/validation/
#   inflating: /content/data/fifawc/preprocess_data/split/validation/cache-f045d6547ecc34a3.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/validation/data-00000-of-00001.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/validation/dataset_info.json
#   inflating: /content/data/fifawc/preprocess_data/split/validation/state.json
#    creating: /content/data/fifawc/preprocess_data/split/train/
#   inflating: /content/data/fifawc/preprocess_data/split/train/data-00000-of-00001.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/train/dataset_info.json
#   inflating: /content/data/fifawc/preprocess_data/split/train/cache-34dbb4e692d93c4a.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/train/state.json
#    creating: /content/data/fifawc/preprocess_data/split/test/
#   inflating: /content/data/fifawc/preprocess_data/split/test/cache-ebfca25d436b137b.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/test/data-00000-of-00001.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/test/dataset_info.json
#   inflating: /content/data/fifawc/preprocess_data/split/test/state.json
#    creating: /content/data/fifawc/preprocess_data/split/mini/
#   inflating: /content/data/fifawc/preprocess_data/split/mini/data-00000-of-00001.arrow
#   inflating: /content/data/fifawc/preprocess_data/split/mini/dataset_info.json
#   inflating: /content/data/fifawc/preprocess_data/split/mini/state.json
#    creating: /content/data/fifawc/preprocess_data/3813/
#   inflating: /content/data/fifawc/preprocess_data/3813/events.jsonl
#    creating: /content/data/fifawc/preprocess_data/3814/
#   inflating: /content/data/fifawc/preprocess_data/3814/events.jsonl
#    creating: /content/data/fifawc/observation_data/
#    creating: /content/data/fifawc/observation_data/split/
#    creating: /content/data/fifawc/observation_data/split/validation/
#   inflating: /content/data/fifawc/observation_data/split/validation/dataset_info.json
#   inflating: /content/data/fifawc/observation_data/split/validation/data-00000-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/validation/data-00001-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/validation/state.json
#    creating: /content/data/fifawc/observation_data/split/train/
#   inflating: /content/data/fifawc/observation_data/split/train/dataset_info.json
#   inflating: /content/data/fifawc/observation_data/split/train/data-00000-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/train/data-00001-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/train/state.json
#    creating: /content/data/fifawc/observation_data/split/test/
#   inflating: /content/data/fifawc/observation_data/split/test/dataset_info.json
#   inflating: /content/data/fifawc/observation_data/split/test/data-00000-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/test/data-00001-of-00002.arrow
#   inflating: /content/data/fifawc/observation_data/split/test/state.json
#    creating: /content/data/fifawc/sar_data/3814/
#   inflating: /content/data/fifawc/sar_data/3814/player.csv
#   inflating: /content/data/fifawc/sar_data/3814/play.csv
#   inflating: /content/data/fifawc/sar_data/3814/ball.csv
#   inflating: /content/data/fifawc/sar_data/3814/players.csv
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cachetools-7.0.6.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/licenses/LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/entry_points.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow-3.11.1.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/WHEEL
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/licenses/LICENSE.markdown-it
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/entry_points.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/markdown_it_py-4.0.0.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/cuda_pathfinder-1.5.3.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/licenses/LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/entry_points.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_skinny-3.11.1.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/entry_points.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mako-1.3.11.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/WHEEL
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/licenses/LICENSE
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/sboms/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/sboms/hf_xet.cyclonedx.json
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/hf_xet-1.4.3.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/licenses/NOTICE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/databricks_sdk-0.105.0.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/google_auth-2.49.2.dist-info/METADATA
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/google/auth/_constants.py
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/google/auth/__pycache__/_constants.cpython-310.pyc
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/WHEEL
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic-2.13.3.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/licenses/LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow_tracing-3.11.1.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/WHEEL
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/licenses/LICENSE.md
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/starlette-1.0.0.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/licenses/LICENSE.PSF
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/greenlet-3.4.0.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/top_level.txt
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/NOTICE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/METADATA
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/s3transfer-0.16.1.dist-info/LICENSE.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/top_level.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/NOTICE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/METADATA
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/botocore-1.42.96.dist-info/LICENSE.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/top_level.txt
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/zip-safe
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/METADATA
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pytz-2026.1.post1.dist-info/LICENSE.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/top_level.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/NOTICE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/METADATA
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/boto3-1.42.96.dist-info/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/transformers/__pycache__/hub_utils.cpython-310.pyc
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/transformers/hub_utils.py
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/auth/db/migrations/versions/add_gateway_permissions.py
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/auth/db/migrations/versions/__pycache__/add_gateway_permissions.cpython-310.pyc
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/__pycache__/gateway_budget.cpython-310.pyc
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/gateway_budget.py
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/9563.b4cc2aa3.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/1912.f3f01f1d.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/2476.ef13e08b.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/2336.66c0d6d7.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/5100.9321ce2c.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/main.d4520ea4.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/8677.26533251.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/1110.41a9df8d.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/4369.7ef04298.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/7267.a73f718d.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/1575.f073c5c3.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/547.26533251.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/1920.24118451.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/3809.bfd74894.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/5997.a73f718d.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/3211.24118451.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/5027.13093132.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/5961.1c4cc586.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/5331.c2236c84.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/6832.85f2cadd.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/3761.1de410b3.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/2868.13093132.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/css/1241.4c488058.chunk.css
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9594.4a474573.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2802.b00eaebb.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5751.d320cee4.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3664.28f15d6c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1575.e28d9446.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6360.5dfa2f1e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2507.8691537e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/main.9479d285.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8462.72725fa6.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/135.d7b46e92.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4890.60820ff3.chunk.js
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/683.f2ca1494.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9026.211b0d5b.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5718.0c15fcf2.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2044.7a80fb0c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2859.e45f3f7c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2119.1cc61222.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8844.a46cd377.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5961.9948d05e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4266.33e61d13.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7633.fffa6578.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8677.51bc5bdb.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/994.daee3089.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4527.640c5bef.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1009.75ea1b85.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2716.f00a09a5.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2365.405c8d5c.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6832.2a130a92.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4704.f1a74eb1.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1241.d42b37ab.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5288.7a73629a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9507.0d97f125.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9686.5e2e2102.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8465.97ff90fb.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5100.b8b45dce.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4768.21f5cfe1.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6019.9c731c0c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6055.223299e9.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3761.1fdcec53.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1544.ddee4c73.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/223.f9d04274.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2107.f7f3aa6c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4139.2b8c5d7d.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1376.c1e4ad35.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5741.3f344ad7.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4499.2207bc03.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1874.a760f2f2.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2584.4b6ff72d.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/547.fca44f3c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4369.9ebaccaa.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4527.640c5bef.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2716.f00a09a5.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1901.96095a2a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8799.8ea2fc76.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5331.d217ef76.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5732.46a71aec.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2010.c3839f5a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5839.f08b21b3.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3977.e56c591c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/161.02ea7838.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2715.7c993007.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5997.191db147.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4152.fcabfa65.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4042.dbf5a38d.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1009.75ea1b85.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8140.a477fc78.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1920.a41e0b36.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5751.d320cee4.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8614.4fa1a573.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7911.1229ea07.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9163.f88ae83f.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9501.04dd54fa.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1521.c781ef94.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/438.9c1694f7.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4489.510e34f4.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1573.92c11743.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4802.e453306a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7271.85008c25.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7238.fcf50630.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1148.cbecc1fe.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1912.06f2c28e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1664.c271bfc2.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2476.0322e26e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8739.b44c9bfb.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4042.dbf5a38d.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2526.da00e691.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2859.e45f3f7c.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8005.06bc3925.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9563.d7fbfe6c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/548.e0d6a99a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3617.cbab4c00.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2336.a3223fe8.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1708.3745c265.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2168.bbe4e7be.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2365.405c8d5c.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9926.6dd0faba.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6264.3daf335a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1078.367d3d92.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/757.bbfb2d16.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3085.7d400399.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/390.01796366.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4435.cb2746a4.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5964.0bc595b4.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2119.1cc61222.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/4499.2207bc03.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5331.d217ef76.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/846.662f7460.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1575.e28d9446.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3932.7a83f11f.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/6301.c81d7737.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7867.e6c08b2d.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9145.7a1e7bbd.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3211.9355c61b.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7136.2eb38360.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/683.f2ca1494.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5679.b063e6f6.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/7267.0a90f94e.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5839.f08b21b3.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3809.9b1aa10a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5027.ae2812d4.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3522.059514d9.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5683.9d6a283a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9347.bdff864d.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8376.d56e6014.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8472.05772852.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/1110.9517e8ad.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9847.51cdabe7.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/688.e6528605.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3617.cbab4c00.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/main.9479d285.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9547.adb31107.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/experimentPage.27e6726a.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/3702.c5d354db.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5910.24eded5b.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/5039.f74fd5f2.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/9686.5e2e2102.chunk.js.LICENSE.txt
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/8799.8ea2fc76.chunk.js.LICENSE.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/static/js/2841.5e2ff522.chunk.js
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/mlflow/server/js/build/lib/notebook-trace-renderer/js/ml-model-trace-renderer.d45f21b3a9e800b3dd66.js
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/licenses/AUTHORS
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/gitpython-3.1.47.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/INSTALLER
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/WHEEL
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/licenses/LICENSE
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/sboms/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/sboms/pydantic-core.cyclonedx.json
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/pydantic_core-2.46.3.dist-info/METADATA
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/RECORD
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/INSTALLER
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/WHEEL
#  extracting: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/top_level.txt
#    creating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/licenses/
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/licenses/LICENSE
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/entry_points.txt
#   inflating: /content/openstarlab_env/lib64/python3.10/site-packages/huggingface_hub-1.12.0.dist-info/METADATA
# /content/openstarlab_env/bin/python3 exists and is a symbolic link.
# /content/openstarlab_env/bin/python exists and is a symbolic link.
# /content/openstarlab_env/bin/python3.10 exists and is a symbolic link.

# %% [markdown]
# class_weightsのみ計算を行い、ファイルを保存する

# %%
# %%writefile train_fifawc2022_class_weight_only.py
import json
from pathlib import Path

from rlearn import RLearn_Model
from rlearn.sports.main_class import TrainAndTestConfig

base_config_path = Path("/content/config/exp_fifawc2022.json")
cached_config_path = Path("/content/config/exp_fifawc2022_with_cached_class_weight.json")
class_weight_cache_path = Path("/content/output/class_weight/exp_fifawc2022_class_weights.pt")

config = json.loads(base_config_path.read_text(encoding="utf-8"))
if "class_weight_fn" not in config:
    raise ValueError(
        "`/content/config/exp_fifawc2022.json` に `class_weight_fn` がありません。"
        "先に `class_weight_fn.type` などを設定してください。"
    )

# Set num_workers to 0 to avoid DataLoader worker issues
config["datamodule"]["num_workers"] = 0

config["class_weight_fn"]["cache_path"] = str(class_weight_cache_path)

cached_config_path.parent.mkdir(parents=True, exist_ok=True)
cached_config_path.write_text(
    json.dumps(config, ensure_ascii=False, indent=4),
    encoding="utf-8",
)

RLearn_Model(
    state_def="PVS"
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=False,
    run_train_and_test=True,
    run_visualize_data=False,
    train_and_test_config=TrainAndTestConfig(
        exp_name="sarsa_attacker",
        run_name="test",
        accelerator="gpu",
        devices=1,
        strategy="auto",
        exp_config_path=str(cached_config_path),
        use_class_weights=True,
        output_base_dir="/content/output",
        class_weight_only=True,
    ),
)

print(f"\n✅ Class weights saved to: {class_weight_cache_path}")
print("✅ Class-weight-only step completed successfully!")
# Out:
# Writing train_fifawc2022_class_weight_only.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python train_fifawc2022_class_weight_only.py
# Out:
# Seed set to 42
# INFO:rlearn.sports.soccer.main_class_soccer.main:loading dataset...
# INFO:rlearn.sports.soccer.main_class_soccer.main:Preprocessing dataset...
# Map (num_proc=8): 100% 1420/1420 [04:31<00:00,  5.23 examples/s]
# INFO:rlearn.sports.soccer.main_class_soccer.main:Preprocessing dataset is done. 271.844566822052 sec
# INFO:rlearn.sports.soccer.main_class_soccer.main:Train dataset size: 1420
# INFO:rlearn.sports.soccer.main_class_soccer.main:Prepare class weights...
# INFO:rlearn.sports.soccer.class_weight.class_weight:No cache found at /content/output/class_weight/exp_fifawc2022_class_weights.pt
# INFO:rlearn.sports.soccer.main_class_soccer.main:Calculating class weights...
# calculating class weights: 100% 3/3 [03:20<00:00, 66.98s/it]
# INFO:rlearn.sports.soccer.class_weight.class_weight:Saving class weights to /content/output/class_weight/exp_fifawc2022_class_weights.pt
# INFO:rlearn.sports.soccer.main_class_soccer.main:Prepare class weights is done. 200.97732663154602 sec
# INFO:rlearn.sports.soccer.main_class_soccer.main:class_weight_only=True: class weights prepared. Skipping training and testing.
#
# ✅ Class weights saved to: /content/output/class_weight/exp_fifawc2022_class_weights.pt
# ✅ Class-weight-only step completed successfully!

# %% [markdown]
# 計算済みのclass_weightsファイルを使用し学習を行う

# %%
# %%writefile train_fifawc2022_with_cached_class_weight.py
import json
from pathlib import Path

from rlearn import RLearn_Model
from rlearn.sports.main_class import TrainAndTestConfig

base_config_path = Path("/content/config/exp_fifawc2022.json")
cached_config_path = Path("/content/config/exp_fifawc2022_with_cached_class_weight.json")
class_weight_cache_path = Path("/content/output/class_weight/exp_fifawc2022_class_weights.pt")

config = json.loads(base_config_path.read_text(encoding="utf-8"))
if "class_weight_fn" not in config:
    raise ValueError(
        "`/content/config/exp_fifawc2022.json` に `class_weight_fn` がありません。"
        "先に `class_weight_fn.type` などを設定してください。"
    )

# Set num_workers to 0 to avoid DataLoader worker issues
config["datamodule"]["num_workers"] = 0

config["class_weight_fn"]["cache_path"] = str(class_weight_cache_path)

cached_config_path.parent.mkdir(parents=True, exist_ok=True)
cached_config_path.write_text(
    json.dumps(config, ensure_ascii=False, indent=4),
    encoding="utf-8",
)

if not class_weight_cache_path.exists():
    raise FileNotFoundError(
        f"Cached class weights not found: {class_weight_cache_path}\n"
        "先に `train_fifawc2022_class_weight_only.py` を実行してください。"
    )

RLearn_Model(
    state_def="PVS"
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=False,
    run_train_and_test=True,
    run_visualize_data=False,
    train_and_test_config=TrainAndTestConfig(
        exp_name="sarsa_attacker",
        run_name="test",
        accelerator="gpu",
        devices=1,
        strategy="auto",
        exp_config_path=str(cached_config_path),
        use_class_weights=True,
        output_base_dir="/content/output",
        class_weight_only=False,
        save_q_values_csv=True,
        max_games_csv=1,
        max_sequences_per_game_csv=5,
    ),
)

print("\n✅ Training completed successfully with cached class weights!")
# Out:
# Writing train_fifawc2022_with_cached_class_weight.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python train_fifawc2022_with_cached_class_weight.py
# Out:
# Seed set to 42
# INFO:rlearn.sports.soccer.main_class_soccer.main:loading dataset...
# INFO:rlearn.sports.soccer.main_class_soccer.main:Preprocessing dataset...
# Map (num_proc=8): 100% 1420/1420 [04:27<00:00,  5.32 examples/s]
# Map (num_proc=8): 100% 1640/1640 [04:41<00:00,  5.84 examples/s]
# Map (num_proc=8): 100% 1390/1390 [04:18<00:00,  5.38 examples/s]
# INFO:rlearn.sports.soccer.main_class_soccer.main:Preprocessing dataset is done. 806.7218885421753 sec
# INFO:rlearn.sports.soccer.main_class_soccer.main:Train dataset size: 1420
# INFO:rlearn.sports.soccer.main_class_soccer.main:Valid dataset size: 1640
# INFO:rlearn.sports.soccer.main_class_soccer.main:Test dataset size: 1390
# INFO:rlearn.sports.soccer.main_class_soccer.main:Prepare class weights...
# INFO:rlearn.sports.soccer.class_weight.class_weight:Loading class weights from /content/output/class_weight/exp_fifawc2022_class_weights.pt
# INFO:rlearn.sports.soccer.main_class_soccer.main:Prepare class weights is done. 0.023468494415283203 sec
# INFO:rlearn.sports.soccer.main_class_soccer.main:Starting training from scratch.
# Experiment with name sarsa_attacker not found. Creating it.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type              ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder       │ GruSeq2SeqEncoder │ 25.0 K │ train │     0 │
# │ 1 │ fc1           │ Linear            │  6.0 K │ train │     0 │
# │ 2 │ fc2           │ Linear            │  1.0 K │ train │     0 │
# │ 3 │ train_metrics │ MetricCollection  │      0 │ train │     0 │
# │ 4 │ val_metrics   │ MetricCollection  │      0 │ train │     0 │
# │ 5 │ test_metrics  │ MetricCollection  │      0 │ train │     0 │
# └───┴───────────────┴───────────────────┴────────┴───────┴───────┘
# Trainable params: 32.0 K
# Non-trainable params: 0
# Total params: 32.0 K
# Total estimated model params size (MB): 0
# Modules in train mode: 19
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO:root:[Epoch 0 | Batch 0] validation total loss: 0.363977, td loss: 0.158438, action loss: 2.336100, l1 loss: 1938.583862
# INFO:root:[Epoch 0 | Batch 1] validation total loss: 0.389699, td loss: 0.183555, action loss: 2.457086, l1 loss: 1938.583862
# INFO:root:[Epoch 0 | Batch 0] train total loss: 0.357949, td loss: 0.152481, action loss: 2.321910, l1 loss: 1938.583862
# INFO:root:[Epoch 0 | Batch 1] train total loss: 0.532861, td loss: 0.340969, action loss: 2.356031, l1 loss: 1801.118774
# INFO:root:[Epoch 0 | Batch 2] train total loss: 0.266309, td loss: 0.086087, action loss: 2.243586, l1 loss: 1690.039795
# INFO:root:[Epoch 0 | Batch 0] validation total loss: 0.225737, td loss: 0.056453, action loss: 2.206621, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 1] validation total loss: 0.223070, td loss: 0.053554, action loss: 2.252815, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 2] validation total loss: 0.237953, td loss: 0.068669, action loss: 2.206554, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 3] validation total loss: 0.218409, td loss: 0.049041, action loss: 2.223144, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 4] validation total loss: 0.238914, td loss: 0.069704, action loss: 2.191779, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 5] validation total loss: 0.222551, td loss: 0.053187, action loss: 2.222619, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 6] validation total loss: 0.213926, td loss: 0.044806, action loss: 2.173757, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 3] train total loss: 0.233335, td loss: 0.063917, action loss: 2.233241, l1 loss: 1582.515869
# INFO:root:[Epoch 0 | Batch 4] train total loss: 0.210122, td loss: 0.051029, action loss: 2.186409, l1 loss: 1481.604248
# INFO:root:[Epoch 0 | Batch 5] train total loss: 0.200193, td loss: 0.050560, action loss: 2.178610, l1 loss: 1387.401733
# INFO:root:[Epoch 0 | Batch 0] validation total loss: 0.192888, td loss: 0.052110, action loss: 2.104821, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 1] validation total loss: 0.193615, td loss: 0.052633, action loss: 2.145620, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 2] validation total loss: 0.209173, td loss: 0.068335, action loss: 2.116891, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 3] validation total loss: 0.180188, td loss: 0.039232, action loss: 2.140436, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 4] validation total loss: 0.206383, td loss: 0.065649, action loss: 2.096113, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 5] validation total loss: 0.186866, td loss: 0.046143, action loss: 2.093871, l1 loss: 1302.536865
# INFO:root:[Epoch 0 | Batch 6] validation total loss: 0.182191, td loss: 0.041580, action loss: 2.071419, l1 loss: 1302.536865
# INFO:rlearn.sports.soccer.main_class_soccer.main:Best checkpoint: /content/output/sarsa_attacker/test/checkpoints/00-6-val_loss=0.1940.ckpt (alias: /content/output/sarsa_attacker/test/checkpoints/best-00-6-val_loss=0.1940.ckpt)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  test_MulticlassAccuracy  │    0.11368195712566376    │
# │  test_MulticlassF1Score   │    0.05712463706731796    │
# │ test_MulticlassPrecision  │    0.14324943721294403    │
# │   test_MulticlassRecall   │    0.11368195712566376    │
# │     test_action_loss      │    2.1509289741516113     │
# │       test_l1_loss        │     1302.536865234375     │
# │         test_loss         │    0.1797451674938202     │
# │       test_td_loss        │    0.03873683512210846    │
# └───────────────────────────┴───────────────────────────┘
# INFO:rlearn.sports.soccer.application.q_values_csv:Saving Q-values to CSV files...
# Processing sequences for Q-value CSV generation: 100% 1420/1420 [06:00<00:00,  3.94it/s]
# INFO:rlearn.sports.soccer.application.q_values_csv:Saved Q-values CSV: /content/output/figures/exp_fifawc2022_with_cached_class_weight/players_q_state/q_values_3814_0.csv
# INFO:rlearn.sports.soccer.application.q_values_csv:Q-values CSV generation completed.
#
# ✅ Training completed successfully with cached class weights!

# %% [markdown]
# # 📄 5.Q値を可視化します。

# %%
# !./openstarlab_env/bin/pip install \
    "adjustText" \
    "pykakasi"
# Out:
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Collecting pykakasi
#   Downloading pykakasi-2.3.0-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in ./openstarlab_env/lib/python3.10/site-packages (from adjustText) (1.24.4)
# Requirement already satisfied: scipy in ./openstarlab_env/lib/python3.10/site-packages (from adjustText) (1.10.1)
# Requirement already satisfied: matplotlib in ./openstarlab_env/lib/python3.10/site-packages (from adjustText) (3.9.0)
# Collecting deprecated
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Collecting jaconv
#   Downloading jaconv-0.5.0-py3-none-any.whl (16 kB)
# Collecting wrapt<3,>=1.10
#   Downloading wrapt-2.1.2-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 KB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (26.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (4.62.1)
# Requirement already satisfied: cycler>=0.10 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (3.3.2)
# Requirement already satisfied: pillow>=8 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (12.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./openstarlab_env/lib/python3.10/site-packages (from matplotlib->adjustText) (1.3.2)
# Requirement already satisfied: six>=1.5 in ./openstarlab_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Installing collected packages: jaconv, wrapt, deprecated, pykakasi, adjustText
# Successfully installed adjustText-1.3.0 deprecated-1.3.1 jaconv-0.5.0 pykakasi-2.3.0 wrapt-2.1.2

# %%
import json

config_path = "/content/config/exp_fifawc2022.json"

with open(config_path, 'r') as f:
    config_data = json.load(f)

print(config_data)
# Modify some values in the config_data dictionary
config_data['dataset']['test_filename'] = '/data/fifawc/observation_data/split/test'

print(f"config: {config_data["dataset"]["test_filename"]}")

with open(config_path, 'w') as f:
    json.dump(config_data, f, indent=4)

print(f"✅ Config updated and saved. Path set to: {config_data['dataset']['test_filename']}")
# Out:
# {'dataset': {'train_filename': '/content/data/fifawc/observation_data/split/train', 'valid_filename': '/content/data/fifawc/observation_data/split/validation', 'test_filename': '/content/data/fifawc/observation_data/split/test', 'preprocess_config': {'state_action_tokenizer': {'type': 'action_only', 'action2id': {'idle': 0, 'right': 1, 'up_right': 2, 'up': 3, 'up_left': 4, 'left': 5, 'down_left': 6, 'down': 7, 'down_right': 8, 'shot': 9, 'dribble': 10, 'through_pass': 11, 'pass': 12, 'cross': 13, 'defensive_action': 14}, 'origin_pos': 'center', 'special_tokens': ['[PAD]']}, 'num_workers': 8, 'preprocess_batch_size': 32}}, 'datamodule': {'type': 'rl_attacker', 'state_action_tokenizer': {'type': 'action_only', 'action2id': {'idle': 0, 'right': 1, 'up_right': 2, 'up': 3, 'up_left': 4, 'left': 5, 'down_left': 6, 'down': 7, 'down_right': 8, 'shot': 9, 'dribble': 10, 'through_pass': 11, 'pass': 12, 'cross': 13, 'defensive_action': 14}, 'origin_pos': 'center', 'special_tokens': ['[PAD]']}, 'num_workers': 8, 'batch_size': 256}, 'model': {'type': 'sarsa_attacker', 'observation_dim': 92, 'sequence_encoder': {'type': 'gru', 'input_size': 64, 'hidden_size': 64, 'num_layers': 1, 'bias': True, 'dropout': 0.0, 'bidirectional': False}, 'vocab_size': 16, 'optimizer': {'type': 'torch::Adam', 'lr': 0.01, 'weight_decay': 1e-05}, 'gamma': 1.0, 'lambda_': 0.0001, 'lambda2_': 0.005}, 'class_weight_fn': {'type': 'exponential', 'cache_path': '/content/data/weight/sarsa_attacker/fifawc/observation_data/exponential_beta0.9.pt', 'beta': 0.9}, 'enable_onball_offball_metrics': False, 'max_epochs': 1, 'val_check_interval': 0.5, 'accumulate_grad_batches': 1, 'offball_action_idx': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'onball_action_idx': [9, 10, 11, 12, 13], 'defensive_action_idx': [14]}
# config: /data/fifawc/observation_data/split/test
# ✅ Config updated and saved. Path set to: /data/fifawc/observation_data/split/test

# %%
# /content/output/ 配下のファイルを openstarlab_env 内に移動
# !mkdir -p /content/output/figures/exp_config/players_q_state
# !mkdir -p /content/openstarlab_env/lib/python3.10/site-packages/rlearn/sports/output/figures/exp_config/
# !cp -r /content/output/figures/exp_fifawc2022_with_cached_class_weight/players_q_state /content/openstarlab_env/lib/python3.10/site-packages/rlearn/sports/output/figures/exp_config/

# 確認
# !ls -R /content/openstarlab_env/lib/python3.10/site-packages/rlearn/sports/output/figures/exp_config/
# Out:
# /content/openstarlab_env/lib/python3.10/site-packages/rlearn/sports/output/figures/exp_config/:
# players_q_state
#
# /content/openstarlab_env/lib/python3.10/site-packages/rlearn/sports/output/figures/exp_config/players_q_state:
# q_values_3814_0.csv

# %%
# %%writefile visualize_qvalues.py
from pathlib import Path
import os
from rlearn import RLearn_Model
from rlearn.sports.main_class import VisualizeDataConfig

config_path = Path("/content/config/exp_fifawc2022.json")

RLearn_Model(
    state_def="PVS"
).run_rlearn(
    run_split_train_test=False,
    run_preprocess_observation=False,
    run_train_and_test=False,
    run_visualize_data=True,
    visualize_config=VisualizeDataConfig(
        exp_config_path=config_path,
        checkpoint_path="/content/output/sarsa_attacker/test/checkpoints/best-00-6-val_loss=0.1940.ckpt",
        model_name="exp_config",
        tracking_file_path="/content/data/fifawc/preprocess_data/3814/events.jsonl",
        match_id="3814",
        sequence_id=0,
        viz_style="bar",
        movie_output_dir="/content/output",
        keep_frames=True
    ),
)

print("\n✅ Updated visualize_qvalues.py without unsupported argument!")
# Out:
# Writing visualize_qvalues.py

# %%
! unset MPLBACKEND && /content/openstarlab_env/bin/python visualize_qvalues.py
# Out:
# Map (num_proc=8): 100% 1390/1390 [04:17<00:00,  5.39 examples/s]
# start loading 3814 0
# 100% 1390/1390 [05:46<00:00,  4.01it/s]
# Warning: Frame count mismatch. Tracking data has 365 frames, but Q-values data has 1825 frames. Trimming to shorter length.
# Generating frames for player: Pedro Miguel (Unknown Team)...
# Movie saved to /content/output/movies/3814_0_Pedro Miguel_bar.mp4
#
# ✅ Updated visualize_qvalues.py without unsupported argument!

# %%
from IPython.display import Image
Image('/content/output/frames/3814_0_Pedro Miguel/frame_0100.png')
